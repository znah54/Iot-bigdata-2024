# %% [markdown]
# ### PyTorch
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c6/PyTorch_logo_black.svg/1920px-PyTorch_logo_black.svg.png"
#      width="700" style="background:white">
#
# - https://pytorch.org/ 공식사이트
# - https://pytorch.kr/ 한글 공식사이트
# - https://tutorials.pytorch.kr/ 튜토리얼만 한글화 사이트

# %% [markdown]
# #### PyTorch 설치
# - CPU 설치
#     - 간단하지만, 그래픽카드 가속 사용할 수 없음
#     - 기본 파이썬 환경 설치
#
# - GPU 설치
#     - 가상환경 생성, 설치
#
# ##### CPU 설치
# - https://pytorch.org/get-started/locally/ 나와있는 Note에서 해당 플랫폼 종류 선택, 명령어 복사 실행
#
# ```python
# !pip install torch torchvision torchaudio
# ```

# %%
# !pip install torch torchvision torchaudio
# torch-2.4.0-cp311-cp311-win_amd64.whl (197.9 MB)
# Out:
# Collecting torch
#   Downloading torch-2.4.0-cp311-cp311-win_amd64.whl.metadata (27 kB)
# Collecting torchvision
#   Downloading torchvision-0.19.0-1-cp311-cp311-win_amd64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.4.0-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in c:\dev\langs\python311\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\dev\langs\python311\lib\site-packages (from torch) (4.9.0)
# Collecting sympy (from torch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in c:\dev\langs\python311\lib\site-packages (from torch) (3.1.3)
# Collecting fsspec (from torch)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2 in c:\dev\langs\python311\lib\site-packages (from torchvision) (1.26.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\dev\langs\python311\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\dev\langs\python311\lib\site-packages (from jinja2->torch) (2.1.4)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading torch-2.4.0-cp311-cp311-win_amd64.whl (197.9 MB)
#    ---------------------------------------- 0.0/197.9 MB ? eta -:--:--
#    ---------------------------------------- 2.4/197.9 MB 11.2 MB/s eta 0:00:18
#     --------------------------------------- 4.7/197.9 MB 11.9 MB/s eta 0:00:17
#    - -------------------------------------- 7.3/197.9 MB 11.6 MB/s eta 0:00:17
#    - -------------------------------------- 8.7/197.9 MB 11.0 MB/s eta 0:00:18
#    -- ------------------------------------- 10.7/197.9 MB 10.2 MB/s eta 0:00:19
#    -- ------------------------------------- 12.8/197.9 MB 10.3 MB/s eta 0:00:18
#    --- ------------------------------------ 15.5/197.9 MB 10.6 MB/s eta 0:00:18
#    --- ------------------------------------ 17.0/197.9 MB 10.1 MB/s eta 0:00:18
#    --- ------------------------------------ 18.6/197.9 MB 10.1 MB/s eta 0:00:18
#    ---- ----------------------------------- 21.2/197.9 MB 10.2 MB/s eta 0:00:18
#    ---- ----------------------------------- 23.6/197.9 MB 10.2 MB/s eta 0:00:18
#    ---- ----------------------------------- 24.6/197.9 MB 9.9 MB/s eta 0:00:18
#    ----- ---------------------------------- 26.0/197.9 MB 9.6 MB/s eta 0:00:18
#    ----- ---------------------------------- 28.3/197.9 MB 9.8 MB/s eta 0:00:18
#    ------ --------------------------------- 30.7/197.9 MB 9.9 MB/s eta 0:00:17
#    ------ --------------------------------- 33.3/197.9 MB 10.0 MB/s eta 0:00:17
#    ------- -------------------------------- 35.4/197.9 MB 10.1 MB/s eta 0:00:17
#    ------- -------------------------------- 37.0/197.9 MB 10.0 MB/s eta 0:00:17
#    ------- -------------------------------- 38.0/197.9 MB 9.7 MB/s eta 0:00:17
#    -------- ------------------------------- 39.8/197.9 MB 9.6 MB/s eta 0:00:17
#    -------- ------------------------------- 41.9/197.9 MB 9.6 MB/s eta 0:00:17
#    -------- ------------------------------- 44.3/197.9 MB 9.7 MB/s eta 0:00:16
#    --------- ------------------------------ 46.9/197.9 MB 9.8 MB/s eta 0:00:16
#    --------- ------------------------------ 49.0/197.9 MB 9.8 MB/s eta 0:00:16
#    ---------- ----------------------------- 50.6/197.9 MB 9.7 MB/s eta 0:00:16
#    ---------- ----------------------------- 51.9/197.9 MB 9.7 MB/s eta 0:00:16
#    ---------- ----------------------------- 54.0/197.9 MB 9.6 MB/s eta 0:00:15
#    ----------- ---------------------------- 56.1/197.9 MB 9.7 MB/s eta 0:00:15
#    ----------- ---------------------------- 58.2/197.9 MB 9.7 MB/s eta 0:00:15
#    ------------ --------------------------- 60.6/197.9 MB 9.7 MB/s eta 0:00:15
#    ------------ --------------------------- 63.2/197.9 MB 9.8 MB/s eta 0:00:14
#    ------------- -------------------------- 65.3/197.9 MB 9.9 MB/s eta 0:00:14
#    ------------- -------------------------- 67.9/197.9 MB 9.9 MB/s eta 0:00:14
#    -------------- ------------------------- 70.3/197.9 MB 10.0 MB/s eta 0:00:13
#    -------------- ------------------------- 72.6/197.9 MB 10.0 MB/s eta 0:00:13
#    --------------- ------------------------ 75.0/197.9 MB 10.0 MB/s eta 0:00:13
#    --------------- ------------------------ 77.6/197.9 MB 10.1 MB/s eta 0:00:12
#    ---------------- -----------------------
MB 10.0 MB/s eta 0:00:01
#    ------------------------------------- - 190.3/197.9 MB 10.0 MB/s eta 0:00:01
#    -------------------------------------- - 192.2/197.9 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  194.0/197.9 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  196.3/197.9 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  197.7/197.9 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  197.7/197.9 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 197.9/197.9 MB 9.7 MB/s eta 0:00:00
# Downloading torchvision-0.19.0-1-cp311-cp311-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 9.4 MB/s eta 0:00:00
# Downloading torchaudio-2.4.0-cp311-cp311-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------  2.4/2.4 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 11.5 MB/s eta 0:00:00
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 10.3 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --------------- ------------------------ 2.4/6.2 MB 11.2 MB/s eta 0:00:01
#    ------------------------------ --------- 4.7/6.2 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 11.1 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, networkx, fsspec, torch, torchvision, torchaudio
# Successfully installed fsspec-2024.6.1 mpmath-1.3.0 networkx-3.3 sympy-1.13.1 torch-2.4.0 torchaudio-2.4.0 torchvision-0.19.0

# %%
import torch

# %%
## 2.4.0+cpu = CPU 용 설치
torch.__version__
# Out:
# '2.4.0+cpu'

# %% [markdown]
# ##### PyTorch GPU 설치
# - NVIDIA GPU에서만 가능, CUDA로 되어있기 때문
# - GPU 설치가 가능한지 먼저 확인
#
# ```python
# !nvidia-smi
# ```

# %%
# !nvidia-smi
# Out:
# Tue Aug  6 12:31:09 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.23                 Driver Version: 536.23       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  | 00000000:01:00.0  On |                  N/A |
# | 50%   38C    P5              13W /  75W |   1449MiB /  4096MiB |     17%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1688    C+G   ....5536.0_x64__8j3eq9eme6ctt\IGCC.exe    N/A      |
# |    0   N/A  N/A      2936    C+G   ...r\AppData\Roaming\Zoom\bin\Zoom.exe    N/A      |
# |    0   N/A  N/A      8208    C+G   ...mpt_builder\LogiAiPromptBuilder.exe    N/A      |
# |    0   N/A  N/A      8616    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A      8908    C+G   ...n\126.0.2592.113\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A      9904    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A      9928    C+G   ...2txyewy\StartMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     10960    C+G   ...tionsPlus\logioptionsplus_agent.exe    N/A      |
# |    0   N/A  N/A     12972    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     13860    C+G   ...n\126.0.2592.113\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     14068    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     15948    C+G   ...n\126.0.2592.113\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     16432    C+G   ...es\Umba Corp\Umba\UmbaWallpaper.exe    N/A      |
# |    0   N/A  N/A     16852    C+G   ...20.0.2210.91.x64\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     18008    C+G   ...20.0.2210.91.x64\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     18556    C+G   ...a\Local\slack\app-4.39.93\slack.exe    N/A      |
# |    0   N/A  N/A     20220    C+G   ...Desktop\app-3.4.2\GitHubDesktop.exe    N/A      |
# |    0   N/A  N/A     20444    C+G   ...n\126.0.2592.113\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     22256    C+G   ...ppData\Roaming\Zoom\bin\CptHost.exe    N/A      |
# |    0   N/A  N/A     22696    C+G   C:\DEV\IDE\Microsoft VS Code\Code.exe     N/A      |
# |    0   N/A  N/A     24400    C+G   ...e\Application\3.27.254.15\whale.exe    N/A      |
# |    0   N/A  N/A     26688    C+G   ...5n1h2txyewy\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     27464    C+G   ...siveControlPanel\SystemSettings.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ##### CUDA Version 12.2
# - CUDA(Compute Unified Device Architecture) - NVIDIA에서 그래픽카드 가속을 위해 만든 기술
# - https://ko.wikipedia.org/wiki/CUDA
#
# ##### CUDA 설치
# - CUDA Toolkit 12.2
#     - https://developer.nvidia.com/cuda-12-2-2-download-archive?target_os=Windows&target_arch=x86_64&target_version=11
# - cuDNN(Deep Neural Network)
#     - CUDA Toolkit에 맞는 버전확인
#     - https://developer.nvidia.com/rdp/cudnn-archive 확인 후 다운로드(단, 로그인 필수)
#     - 압축을 풀고 CUDA 경로(C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.2)에 복사/붙여넣기
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### GPU용 파이썬 가상환경 만들기
# - GPU PyTorch는 설치로그를 봐야하기 때문에 명령프롬프트에서 진행
#
# - 터미널 오픈
#     - virtualenv 확인
#     - pip install virtualenv
#     - virtualenv torch_env
# - 가상환경 활성화
#     - cd gpu_env\Scripts\activate
#
# - PyTorch GPU 설치
#     - 파이토치 GetStarted 사이트에서 확인 명령어
#     - pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %% [markdown]
# ##### 파이토치 GPU 확인

# %%
import torch

# %%
## 2.4.0+cu121 --> CUDA 12.1 버전의 PyTorch
torch.__version__
# Out:
# '2.4.0+cu121'

# %%
## CUDA 쓸 수 있는지 확인
torch.cuda.is_available()
# Out:
# True

# %%
## 설치된 CUDA가 동작하는 그래픽카드 정보확인
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce GTX 1650 with Max-Q Design'

# %% [markdown]
# ##### 이제부터 GPU 가속으로 파이토치(텐서플로 가능) 딥러닝을 할 수 있음
